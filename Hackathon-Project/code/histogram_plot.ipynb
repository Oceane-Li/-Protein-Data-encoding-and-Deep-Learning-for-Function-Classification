# %% [markdown]
# # Histrogram plots

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read the data
data = pd.read_csv('eval_result.txt', sep='  ')
data["Code"] = pd.read_csv('code.txt', sep='  ')
data
# Out:
# C:\Users\antoi_lfffcmq\AppData\Local\Temp\ipykernel_21820\773943905.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv('eval_result.txt', sep='  ')
# C:\Users\antoi_lfffcmq\AppData\Local\Temp\ipykernel_21820\773943905.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data["Code"] = pd.read_csv('code.txt', sep='  ')
#     precision    recall  f1-score  support       Code
# 0    0.926034  0.908787  0.917329   2094.0  IPR003593
# 1    0.963571  0.934858  0.948998   1443.0  IPR005225
# 2    0.952931  0.967538  0.960179   1109.0  IPR006195
# ...

# %%
#plot the f1 score
plt.figure(figsize=(20,20))
plt.bar(data['Code'], data['f1-score'], label='f1')
plt.xlabel('InterPro')
plt.xticks(rotation=90)
plt.ylabel('F1 score')
plt.title('F1 score over InterPro for deep learning model')
# Out:
# Text(0.5, 1.0, 'F1 score over InterPro for deep learning model')

# %%
# Read the data
data = pd.read_csv("Project06_avec_multiple_labels_svc.csv", sep = "\s+|\t+|\s+\t+|\t+\s+")
data["Code"] = pd.read_csv('code.txt', sep='  ')
data
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\antoi_lfffcmq\AppData\Local\Temp\ipykernel_21820\2238279269.py:2: SyntaxWarning: invalid escape sequence '\s'
#   data = pd.read_csv("Project06_avec_multiple_labels_svc.csv", sep = "\s+|\t+|\s+\t+|\t+\s+")
# C:\Users\antoi_lfffcmq\AppData\Local\Temp\ipykernel_21820\2238279269.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv("Project06_avec_multiple_labels_svc.csv", sep = "\s+|\t+|\s+\t+|\t+\s+")
# ...

# %%
#plot the f1 score
plt.figure(figsize=(20,20))
plt.bar(data['Code'], data['f1-score'], label='f1')
plt.xlabel('InterPro')
plt.xticks(rotation=90)
plt.ylabel('F1 score')
plt.title('F1 score over InterPro for machine learning model')
# Out:
# Text(0.5, 1.0, 'F1 score over InterPro for machine learning model')
